# %% [markdown]
# # Truss Example 2
#
# Use what you've learned in the previous sections to write a code that uses the direct stiffness method to determine:
# - the nodal displacements
# - reaction forces
# - internal member forces
#
# for the structure shown below. Note that members A-G all have a length of 10 m.
#
# **This is going to be a challenge but you know enough now to complete this! 👍**

# %% [markdown]
# ![img1.png](attachment:img1.png)

# %%
#DEPENDENCIES
import math #Math functionality
import numpy as np #Numpy for working with arrays
import matplotlib.pyplot as plt #Plotting functionality 

#Constants
E = 200*10**9 #(N/m^2)
A = 0.005 #(m^2)
